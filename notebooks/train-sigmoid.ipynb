# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Seg3D/KiTS2019/kits19
# Out:
# /content/drive/MyDrive/Seg3D/KiTS2019/kits19

# %%
# !pip install -r requirements.txt

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Mar 18 15:19:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from segment.training.train import runner

# %% [markdown]
# **Training**

# %%
runner(
    train_dataset_path="output/data/train_dataset.pt",
    valid_dataset_path="output/data/valid_dataset.pt",
    class_weight_path="output/class_weight.npy",
    config_dir="configs/segment_pipeline.yaml",
    model_name_or_path="UnetRes_v2",
    output_dir="output/models/best_model_1803.pt",
    cache_dir=None,
    freeze_feature=False,
    num_classes=2,
    act_func="sigmoid",
    num_train_epochs=100,
    log_dir="output/logs_1803.csv",
    do_train=True, 
    do_eval=False
)
# Out:
# INFO:segment.utils.file_utils:class weight saved at output/class_weight.npy
# class_weight: [[[[[0.25]]]
#
#
#   [[[0.75]]]]]
#
# epoch 0/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  1.1476 , dsc :  0.2534 , dsc_organ :  0.3195 , dsc_tumor :  0.0284 ,
# epoch 1/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.9300 , dsc :  0.5319 , dsc_organ :  0.6315 , dsc_tumor :  0.0586 ,
# epoch 2/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.7684 , dsc :  0.6153 , dsc_organ :  0.7519 , dsc_tumor :  0.0701 ,
# epoch 3/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.6816 , dsc :  0.6577 , dsc_organ :  0.8013 , dsc_tumor :  0.1126 ,
# epoch 4/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.6324 , dsc :  0.6997 , dsc_organ :  0.8166 , dsc_tumor :  0.1677 ,
# epoch 5/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.6092 , dsc :  0.7207 , dsc_organ :  0.8234 , dsc_tumor :  0.1784 ,
# epoch 6/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.5638 , dsc :  0.7641 , dsc_organ :  0.8346 , dsc_tumor :  0.2524 ,
# epoch 7/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.5627 , dsc :  0.7617 , dsc_organ :  0.8314 , dsc_tumor :  0.2511 ,
# epoch 8/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.5415 , dsc :  0.7731 , dsc_organ :  0.8366 , dsc_tumor :  0.2763 ,
# epoch 9/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.5263 , dsc :  0.7853 , dsc_organ :  0.8458 , dsc_tumor :  0.2999 ,
# epoch 10/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4949 , dsc :  0.7994 , dsc_organ :  0.8433 , dsc_tumor :  0.3471 ,
# epoch 11/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4804 , dsc :  0.7995 , dsc_organ :  0.8504 , dsc_tumor :  0.3774 ,
# epoch 12/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4626 , dsc :  0.8149 , dsc_organ :  0.8563 , dsc_tumor :  0.3896 ,
# epoch 13/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4397 , dsc :  0.8226 , dsc_organ :  0.8571 , dsc_tumor :  0.4261 ,
# epoch 14/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4591 , dsc :  0.8114 , dsc_organ :  0.8508 , dsc_tumor :  0.3995 ,
# epoch 15/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4528 , dsc :  0.8145 , dsc_organ :  0.8472 , dsc_tumor :  0.4052 ,
# epoch 16/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4435 , dsc :  0.8172 , dsc_organ :  0.8623 , dsc_tumor :  0.4129 ,
# epoch 17/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4411 , dsc :  0.8159 , dsc_organ :  0.8545 , dsc_tumor :  0.4257 ,
# epoch 18/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4232 , dsc :  0.8217 , dsc_organ :  0.8515 , dsc_tumor :  0.4516 ,
# epoch 19/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4389 , dsc :  0.8093 , dsc_organ :  0.8534 , dsc_tumor :  0.4356 ,
# epoch 20/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4256 , dsc :  0.8194 , dsc_organ :  0.8595 , dsc_tumor :  0.4431 ,
# epoch 21/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.4451 , dsc :  0.7953 , dsc_organ :  0.8330 , dsc_tumor :  0.4305 ,
# epoch 22/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3996 , dsc :  0.8304 , dsc_organ :  0.8663 , dsc_tumor :  0.4853 ,
# epoch 23/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3839 , dsc :  0.8360 , dsc_organ :  0.8679 , dsc_tumor :  0.5085 ,
# epoch 24/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3630 , dsc :  0.8523 , dsc_organ :  0.8775 , dsc_tumor :  0.5363 ,
# epoch 25/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3687 , dsc :  0.8620 , dsc_organ :  0.8829 , dsc_tumor :  0.5100 ,
# epoch 26/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3759 , dsc :  0.8386 , dsc_organ :  0.8719 , dsc_tumor :  0.5179 ,
# epoch 27/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3664 , dsc :  0.8521 , dsc_organ :  0.8836 , dsc_tumor :  0.5262 ,
# epoch 28/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3721 , dsc :  0.8466 , dsc_organ :  0.8681 , dsc_tumor :  0.5233 ,
# epoch 29/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3474 , dsc :  0.8512 , dsc_organ :  0.8719 , dsc_tumor :  0.5641 ,
# epoch 30/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3381 , dsc :  0.8580 , dsc_organ :  0.8766 , dsc_tumor :  0.5769 ,
# epoch 31/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3245 , dsc :  0.8701 , dsc_organ :  0.8896 , dsc_tumor :  0.5924 ,
# epoch 32/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3381 , dsc :  0.8723 , dsc_organ :  0.8877 , dsc_tumor :  0.5639 ,
# epoch 33/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3342 , dsc :  0.8652 , dsc_organ :  0.8806 , dsc_tumor :  0.5718 ,
# epoch 34/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3188 , dsc :  0.8672 , dsc_organ :  0.8799 , dsc_tumor :  0.6028 ,
# epoch 35/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3247 , dsc :  0.8807 , dsc_organ :  0.8955 , dsc_tumor :  0.5752 ,
# epoch 36/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3388 , dsc :  0.8782 , dsc_organ :  0.8921 , dsc_tumor :  0.5461 ,
# epoch 37/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3134 , dsc :  0.8832 , dsc_organ :  0.8980 , dsc_tumor :  0.5988 ,
# epoch 38/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3413 , dsc :  0.8522 , dsc_organ :  0.8642 , dsc_tumor :  0.5777 ,
# epoch 39/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3294 , dsc :  0.8569 , dsc_organ :  0.8679 , dsc_tumor :  0.5908 ,
# epoch 40/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3236 , dsc :  0.8591 , dsc_organ :  0.8797 , dsc_tumor :  0.5957 ,
# epoch 41/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3204 , dsc :  0.8680 , dsc_organ :  0.8882 , dsc_tumor :  0.5943 ,
# epoch 42/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3147 , dsc :  0.8608 , dsc_organ :  0.8793 , dsc_tumor :  0.6134 ,
# epoch 43/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3220 , dsc :  0.8566 , dsc_organ :  0.8800 , dsc_tumor :  0.5978 ,
# epoch 44/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3016 , dsc :  0.8777 , dsc_organ :  0.8945 , dsc_tumor :  0.6211 ,
# epoch 45/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3065 , dsc :  0.8713 , dsc_organ :  0.8881 , dsc_tumor :  0.6152 ,
# epoch 46/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3084 , dsc :  0.8864 , dsc_organ :  0.9072 , dsc_tumor :  0.5994 ,
# epoch 47/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2939 , dsc :  0.8807 , dsc_organ :  0.8928 , dsc_tumor :  0.6444 ,
# epoch 48/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2940 , dsc :  0.8769 , dsc_organ :  0.8872 , dsc_tumor :  0.6444 ,
# epoch 49/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2964 , dsc :  0.8870 , dsc_organ :  0.9011 , dsc_tumor :  0.6231 ,
# epoch 50/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3121 , dsc :  0.8667 , dsc_organ :  0.8839 , dsc_tumor :  0.6090 ,
# epoch 51/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2867 , dsc :  0.8854 , dsc_organ :  0.9028 , dsc_tumor :  0.6406 ,
# epoch 52/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3388 , dsc :  0.8454 , dsc_organ :  0.8685 , dsc_tumor :  0.5838 ,
# epoch 53/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2930 , dsc :  0.8731 , dsc_organ :  0.8914 , dsc_tumor :  0.6422 ,
# epoch 54/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2908 , dsc :  0.8870 , dsc_organ :  0.9095 , dsc_tumor :  0.6301 ,
# epoch 55/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3594 , dsc :  0.8303 , dsc_organ :  0.8672 , dsc_tumor :  0.5506 ,
# epoch 56/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3010 , dsc :  0.8721 , dsc_organ :  0.8905 , dsc_tumor :  0.6230 ,
# epoch 57/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2954 , dsc :  0.8936 , dsc_organ :  0.9011 , dsc_tumor :  0.6169 ,
# epoch 58/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2759 , dsc :  0.8945 , dsc_organ :  0.9098 , dsc_tumor :  0.6543 ,
# epoch 59/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2787 , dsc :  0.8942 , dsc_organ :  0.9080 , dsc_tumor :  0.6488 ,
# epoch 60/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2911 , dsc :  0.8746 , dsc_organ :  0.8905 , dsc_tumor :  0.6400 ,
# epoch 61/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.3163 , dsc :  0.8581 , dsc_organ :  0.8803 , dsc_tumor :  0.6091 ,
# epoch 62/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2884 , dsc :  0.8735 , dsc_organ :  0.8911 , dsc_tumor :  0.6453 ,
# epoch 63/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2676 , dsc :  0.8906 , dsc_organ :  0.9081 , dsc_tumor :  0.6691 ,
# epoch 64/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2715 , dsc :  0.8935 , dsc_organ :  0.9086 , dsc_tumor :  0.6573 ,
# epoch 65/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2714 , dsc :  0.8914 , dsc_organ :  0.9045 , dsc_tumor :  0.6559 ,
# epoch 66/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2594 , dsc :  0.9018 , dsc_organ :  0.9109 , dsc_tumor :  0.6779 ,
# epoch 67/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2721 , dsc :  0.8844 , dsc_organ :  0.8966 , dsc_tumor :  0.6705 ,
# epoch 68/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2940 , dsc :  0.8750 , dsc_organ :  0.8940 , dsc_tumor :  0.6338 ,
# epoch 69/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2690 , dsc :  0.8868 , dsc_organ :  0.9006 , dsc_tumor :  0.6727 ,
# epoch 70/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2797 , dsc :  0.8758 , dsc_organ :  0.8834 , dsc_tumor :  0.6710 ,
# epoch 71/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2804 , dsc :  0.8816 , dsc_organ :  0.8908 , dsc_tumor :  0.6597 ,
# epoch 72/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2611 , dsc :  0.8955 , dsc_organ :  0.9061 , dsc_tumor :  0.6793 ,
# epoch 73/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2409 , dsc :  0.9056 , dsc_organ :  0.9076 , dsc_tumor :  0.7164 ,
# epoch 74/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2668 , dsc :  0.9040 , dsc_organ :  0.9211 , dsc_tumor :  0.6544 ,
# epoch 75/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2514 , dsc :  0.8948 , dsc_organ :  0.9052 , dsc_tumor :  0.6930 ,
# epoch 76/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2980 , dsc :  0.8739 , dsc_organ :  0.8956 , dsc_tumor :  0.6334 ,
# epoch 77/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2717 , dsc :  0.8870 , dsc_organ :  0.9106 , dsc_tumor :  0.6624 ,
# epoch 78/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2786 , dsc :  0.8853 , dsc_organ :  0.9030 , dsc_tumor :  0.6516 ,
# epoch 79/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2781 , dsc :  0.8935 , dsc_organ :  0.9069 , dsc_tumor :  0.6525 ,
# epoch 80/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2610 , dsc :  0.8955 , dsc_organ :  0.9083 , dsc_tumor :  0.6831 ,
# epoch 81/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2675 , dsc :  0.8801 , dsc_organ :  0.8951 , dsc_tumor :  0.6787 ,
# epoch 82/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2727 , dsc :  0.9038 , dsc_organ :  0.9145 , dsc_tumor :  0.6485 ,
# epoch 83/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2584 , dsc :  0.9014 , dsc_organ :  0.9116 , dsc_tumor :  0.6819 ,
# epoch 84/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2769 , dsc :  0.8930 , dsc_organ :  0.9020 , dsc_tumor :  0.6657 ,
# epoch 85/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2433 , dsc :  0.9065 , dsc_organ :  0.9093 , dsc_tumor :  0.7198 ,
# epoch 86/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2332 , dsc :  0.9153 , dsc_organ :  0.9216 , dsc_tumor :  0.7144 ,
# epoch 87/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2629 , dsc :  0.8895 , dsc_organ :  0.9003 , dsc_tumor :  0.6817 ,
# epoch 88/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2783 , dsc :  0.8929 , dsc_organ :  0.9141 , dsc_tumor :  0.6441 ,
# epoch 89/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2707 , dsc :  0.8924 , dsc_organ :  0.9034 , dsc_tumor :  0.6610 ,
# epoch 90/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2492 , dsc :  0.8957 , dsc_organ :  0.9020 , dsc_tumor :  0.7047 ,
# epoch 91/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2415 , dsc :  0.9032 , dsc_organ :  0.9091 , dsc_tumor :  0.7171 ,
# epoch 92/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2507 , dsc :  0.8974 , dsc_organ :  0.9046 , dsc_tumor :  0.7036 ,
# epoch 93/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2301 , dsc :  0.9031 , dsc_organ :  0.9052 , dsc_tumor :  0.7434 ,
# epoch 94/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2388 , dsc :  0.9069 , dsc_organ :  0.9206 , dsc_tumor :  0.7150 ,
# epoch 95/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2491 , dsc :  0.8935 , dsc_organ :  0.9015 , dsc_tumor :  0.7253 ,
# epoch 96/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2422 , dsc :  0.9031 , dsc_organ :  0.9098 , dsc_tumor :  0.7031 ,
# epoch 97/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2826 , dsc :  0.8791 , dsc_organ :  0.8963 , dsc_tumor :  0.6571 ,
# epoch 98/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# train loss :  0.2897 , dsc :  0.8820 , dsc_organ :  0.8944 , dsc_tumor :  0.6584 ,
# epoch 99/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# INFO:segment.utils.file_utils:Save logs at directory: output/logs_1803.csv
# INFO:segment.utils.file_utils:Save model at directory: output/models/best_model_1803.pt
# train loss :  0.2707 , dsc :  0.8714 , dsc_organ :  0.8885 , dsc_tumor :  0.6777 ,
